# %% [markdown]
# <a href="https://colab.research.google.com/github/jugernaut/Numerico2021/blob/desarrollo/Inicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jugernaut/Numerico2021.git
# Out:
# Cloning into 'Numerico2021'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 3104 (delta 7), reused 0 (delta 0), pack-reused 3084
# Receiving objects: 100% (3104/3104), 18.43 MiB | 33.70 MiB/s, done.
# Resolving deltas: 100% (1971/1971), done.

# %%
# !rm -r Numerico2021/

# %% [markdown]
# # Introducción
#
# Introducción al proyecto $x_1$ xsaxas $F(\vec{x})$
#
# $$
# y_1 \tag{1}
# $$

# %% [markdown]
# ## Sección 2
#
# ![Captura de pantalla de 2020-09-22 02-10-11.png](data:image/png;base64,...)

# %% [markdown]
# ### Ejemplo
#
# <img src="https://github.com/jugernaut/Numerico2021/blob/desarrollo/Figuras/Normas/p1.png?raw=1" width="150">
#
# ![norma 1](https://docs.google.com/uc?export=download&id=1FKEBbI-dkOV0zmuoIBF3XZ2wxrLsTe5l)
